# %% [markdown]
# <a href="https://colab.research.google.com/github/brendharosa/primeiro1/blob/main/Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota1 = 6.0
nota2 = 8.5
nota3 = 9.5

media = (nota1 + nota2 + nota3) / 3

print("Nota 1:", nota1)
print("Nota 2:", nota2)
print("Nota 3:", nota3)
print("Média:", media)
# Out:
# Nota 1: 6.0
# Nota 2: 8.5
# Nota 3: 9.5
# Média: 8.0

# %%
nome = input("Digite o nome do aluno: ")

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))

media = (nota1 + nota2 + nota3) / 3

print("\n--- RELATÓRIO DO ALUNO ---")
print("Aluno:", nome)
print("Nota 1:", nota1)
print("Nota 2:", nota2)
print("Nota 3:", nota3)
print("Média:", media)
# Out:
# Digite o nome do aluno: brendha
# Digite a primeira nota: 9.0
# Digite a segunda nota: 6.0
# Digite a terceira nota: 7.0
#
# --- RELATÓRIO DO ALUNO ---
# Aluno: brendha
# Nota 1: 9.0
# Nota 2: 6.0
# Nota 3: 7.0
# Média: 7.333333333333333
