# %% [markdown]
# <a href="https://colab.research.google.com/github/brendharosa/primeiro1/blob/main/Aula%2004%20teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota = float (input("Digite o valor da nota: "))
if nota < 60:
 print ("Sua nota {} foi insuficiente! ".format(nota) )
else:
  print ("Sua nota {} foi suficiente ".format(nota) )
# Out:
# Digite o valor da nota: 50
# Sua nota 50.0 foi insuficiente!
